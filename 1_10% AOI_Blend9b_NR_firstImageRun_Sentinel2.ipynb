# %% [markdown]
# # Imports and Authorizations

# %%
# Imports used in this notebook.
import ee
import os
import folium
import sys
import time
import shutil
import pandas as pd
import seaborn as sea
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from ee import batch
from matplotlib import cm
from google.colab import drive


# Must authenticate your EE account before use of the package.
#ee.Authenticate()
#ee.Initialize()
ee.Authenticate()
ee.Initialize(opt_url='https://earthengine-highvolume.googleapis.com')

# This is how we can access our drive to get the correlation product.
drive.mount('/content/gdrive')
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=P3LWjVhk_yFFd4lD84yRiog1qdT5qRQCBeaoaU0_G84&tc=dfRTYU4amzPSDJBRjyXX4DypLNf5yNUaOTiqJztYTm0&cc=9g0yOoCNSNVWOfSHcMe9uPH4LFTbp2CfDDtzGwUnvDI
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AVHEtk5YWwk8iE0MDM-mClQiCIr4ySlB2adl-oUdBpTg2HsU87Liu6X9ktQ
#
# Successfully saved authorization token.
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Set the IRL AOI.

# %%
#Florida DEP bounds
#Indian River Lagoon
siteName = 'Indian River Lagoon'
# Must be 3 characters long
siteName_2char = 'IRL'
upperLeft = [-80.763739, 28.621909]
lowerRight = [-80.503601,  27.605387]
# upperLeft = [-80.763739, 28.621909]
# lowerRight = [-80.533771,   28.063011]

# Define a region of interest to filter our collection.
roi = ee.Geometry.Rectangle(upperLeft[0], upperLeft[1], lowerRight[0], lowerRight[1])

# %% [markdown]
# # Select our Landsat 8 imagery

# %%
# List of dates.
date_list = [
ee.Date('2020-01-01'),
ee.Date('2020-01-06'),
ee.Date('2020-01-16'),
ee.Date('2020-02-03'),
ee.Date('2020-02-08'),
ee.Date('2020-03-01'),
ee.Date('2020-03-14'),
ee.Date('2020-03-24'),
ee.Date('2020-03-29'),
ee.Date('2020-04-03'),
ee.Date('2020-04-08'),
ee.Date('2020-05-05'),
ee.Date('2020-05-20'),
ee.Date('2020-06-24'),
ee.Date('2020-06-29'),
ee.Date('2020-07-14'),
ee.Date('2020-07-19'),
ee.Date('2020-07-24'),
ee.Date('2020-08-08'),
ee.Date('2020-08-13'),
ee.Date('2020-09-02'),
ee.Date('2020-09-17'),
ee.Date('2020-10-15'),
ee.Date('2020-10-27'),
ee.Date('2020-11-24'),
ee.Date('2020-12-09'),
ee.Date('2020-12-21'),
ee.Date('2020-12-29'),
ee.Date('2021-01-05'),
ee.Date('2021-01-20'),
ee.Date('2021-01-28'),
ee.Date('2021-02-02'),
ee.Date('2021-02-19'),
ee.Date('2021-02-22'),
ee.Date('2021-02-24'),
ee.Date('2021-02-27'),
ee.Date('2021-03-01'),
ee.Date('2021-03-04'),
ee.Date('2021-03-11'),
ee.Date('2021-03-14'),
ee.Date('2021-03-19'),
ee.Date('2021-03-24'),
ee.Date('2021-04-05'),
ee.Date('2021-04-10'),
ee.Date('2021-04-30'),
ee.Date('2021-05-05'),
ee.Date('2021-05-10'),
ee.Date('2021-05-15'),
ee.Date('2021-05-25'),
ee.Date('2021-06-09'),
ee.Date('2021-07-19'),
ee.Date('2021-07-29'),
ee.Date('2021-09-07'),
ee.Date('2021-09-22'),
ee.Date('2021-09-27'),
ee.Date('2021-09-30'),
ee.Date('2021-10-02'),
ee.Date('2021-10-12'),
ee.Date('2021-11-16'),
ee.Date('2021-11-26'),
ee.Date('2021-11-29'),
ee.Date('2021-12-04'),
ee.Date('2021-12-06'),
ee.Date('2021-12-09'),
ee.Date('2021-12-16'),
ee.Date('2021-12-24'),
ee.Date('2021-12-26'),
ee.Date('2021-12-29'),
ee.Date('2022-01-03'),
ee.Date('2022-01-08'),
ee.Date('2022-01-15'),
ee.Date('2022-01-18'),
ee.Date('2022-01-20'),
ee.Date('2022-01-30'),
ee.Date('2022-02-04'),
ee.Date('2022-02-12'),
ee.Date('2022-02-14'),
ee.Date('2022-02-22'),
ee.Date('2022-02-24'),
ee.Date('2022-03-04'),
ee.Date('2022-03-21'),
ee.Date('2022-03-26'),
ee.Date('2022-04-05'),
ee.Date('2022-04-10'),
ee.Date('2022-04-25'),
ee.Date('2022-05-05'),
ee.Date('2022-05-15'),
ee.Date('2022-06-24'),
ee.Date('2022-07-19'),
ee.Date('2022-07-29'),
ee.Date('2022-08-18'),
ee.Date('2022-09-07'),
ee.Date('2022-09-12'),
ee.Date('2022-09-22'),
ee.Date('2022-10-02'),
ee.Date('2022-10-05'),
ee.Date('2022-10-07'),
ee.Date('2022-10-25'),
ee.Date('2022-10-27'),
ee.Date('2022-10-30'),
ee.Date('2022-11-01'),
ee.Date('2022-11-04'),
ee.Date('2022-11-11'),
ee.Date('2022-11-29'),
ee.Date('2022-12-01'),
ee.Date('2022-12-04'),
ee.Date('2022-12-06'),
ee.Date('2022-12-09'),
ee.Date('2022-12-29'),
]
# 20 percent exception
# ee.Date('2022-08-01'),

# ee.Date('2020-01-11'),
# ee.Date('2020-01-14'),
# ee.Date('2020-01-26'),
# ee.Date('2020-02-13'),
# ee.Date('2020-02-18'),
# ee.Date('2020-02-20'),
# ee.Date('2020-02-28'),
# ee.Date('2020-03-19'),
# ee.Date('2020-03-26'),
# ee.Date('2020-08-23'),
# ee.Date('2020-09-10'),
# ee.Date('2020-10-07'),
# ee.Date('2020-10-25'),
# ee.Date('2020-10-30'),
# ee.Date('2020-11-04'),
# ee.Date('2020-11-14'),
# ee.Date('2020-11-26'),
# ee.Date('2020-12-11'),
# ee.Date('2021-01-18'),
# ee.Date('2021-03-09'),
# ee.Date('2021-04-15'),
# ee.Date('2021-07-24'),
# ee.Date('2021-08-18'),
# ee.Date('2021-09-02'),
# ee.Date('2021-10-15'),
# ee.Date('2021-10-17'),
# ee.Date('2021-10-20'),
# ee.Date('2021-10-22'),
# ee.Date('2021-10-30'),
# ee.Date('2021-11-11'),
# ee.Date('2021-12-01'),
# ee.Date('2021-12-31'),
# ee.Date('2022-01-13'),
# ee.Date('2022-02-02'),
# ee.Date('2022-02-27'),
# ee.Date('2022-03-06'),
# ee.Date('2022-03-19'),
# ee.Date('2022-04-23'),
# ee.Date('2022-04-30'),
# ee.Date('2022-07-04'),
# ee.Date('2022-07-09'),

# ee.Date('2022-08-03'),


im_list = []

# Start Standard code for processing images from a collection.
for date in date_list:

  # Bring in our imagery.
  coll = (ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
              .filterBounds(roi)
              .filterDate(date, date.advance(1,'day')))

  # Clip our input image to our region of interest.
  # Set the name of the original image to our new image.
  water = coll.mosaic().clip(roi).set({'name':coll.first().get('system:index')})

  # Add the newly created image to the empty list created above.
  im_list += [water]

# Make an EE Collection out of the list we created.
im_list = ee.ImageCollection(im_list)

# %% [markdown]
# # Begin analysis

# %%
# Name the parent folder where we're writing our output files.
# output_folder = '/content/gdrive/Shared drives/Asgard/FL_DEP_Seagrass_KSU_ST/Sentinel2'
output_folder = '/content/gdrive/My Drive/test_FL_DEP'

# Define the Sentinel-2 bands to extract
non_ee_band_list = ['B1','B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A']

# For reductions.
native_res = 10
maxP = 1e6

# Array of wavelength corrections for Sentinel-2 sensor.
wl = ee.Array([443.9,496.6,560.0,664.5,703.9,740.2,782.5,835.1,864.8])
# Nominal Copernicus S2A Wavelength Values
# wl = ee.Array([442.7,492.7,559.8,664.4,704.1,740.5,782.8,832.8,864.7])
# Name the band combo for outputs.
bandCombo="B1-B8A"

""" Bands and Wavelength Array to select. You can add or subtract any you'd like here and the code
    below will account for the change throughout the workflow. """

# Use this for the derivative calculation.
band_list_early_length = len(non_ee_band_list)
# We use this everywhere else after the derivative calc (original band list x2).
#band_list_length = band_list_early_length * 2
band_list_length = band_list_early_length
# Use this in a couple for loops throughout the code.
band_list_forLoops = range(band_list_length)

# %%
def derivative_images(water):

  """This section is devoted to modifying the image, making it suitable for
     the Derivative Spectra function, and running the DS function."""

  # This function masks the cloudy pixels and identifies the water pixels.
  def get_water(image):

    # Water with cloud check, but note this is the not bit addition method.
    water_pixels = (image.select('QA60').eq(0).And(image.select('SCL').eq(6)))
    # water_pixels=image.select('QA60')
    # cloudBitMask=1 << 10
    # cirrusBitMask=1 << 11
    # mask = water_pixels.bitwiseAnd(cloudBitMask).eq(0).And(water_pixels.bitwiseAnd(cirrusBitMask).eq(0))
    # water_pixels = (image.select('SCL').eq(6).And(image.select('SCL').lt(7)))
    # Mask all non-water pixels in the image.
    image = image.updateMask(water_pixels)

    return image

  # Run the S2 mask on the test images.
  water_mask = get_water(water)

  # Binary reducer, which returns 1 everywhere that water hasn't been masked.
  mask_image = water_mask.reduce(ee.Reducer.anyNonZero())

  # Any pixels passing the pixel mask will now be polygonized.
  water_geom = mask_image.reduceToVectors(scale = native_res, geometry = roi, maxPixels = maxP, bestEffort = True, tileScale = 16)

  # This function will select the bands of importance and clip the raster.
  def selAndClip(masked_image,geo):

    clipped = masked_image.select(non_ee_band_list).clip(geo)

    return clipped.toDouble()

  # Run the select and clip function on the test images, converts the pixels values to double precision.
  clipped_image = selAndClip(water_mask,water_geom)

  # Add code below to divide the reflectance bands by 10^4 to scale from 0 to 1
  clipped_image = clipped_image.multiply(0.0001)

  # This function calculates the derivative bands that will also be used in the PCA analysis.
  def derivativeSpectra(img,numBands):

    drdlraster = None

    for i in range(numBands):

      # Special case of the equation is required for the first band.
      if i == 0:
        drdlraster = img.expression(
          '(secondBand - firstBand)/(secondIndex - firstIndex)',
          {
          'secondBand': img.select(i+1),
          'firstBand': img.select(i),
          'secondIndex': wl.get([i+1]),
          'firstIndex': wl.get([i])
          }).rename('image_Index' + str(i) + '_derivative')

      # Special case of the equation is required for the last band.
      elif i == (numBands-1):

        drdlraster = img.expression(
          '(secondBand - firstBand)/(secondIndex - firstIndex)',
          {
          'secondBand': img.select(i),
          'firstBand': img.select(i-1),
          'secondIndex': wl.get([i]),
          'firstIndex': wl.get([i-1])
          }).rename('image_Index' + str(i) + '_derivative')

      # Apply equation for all other bands in the image.
      else:
        drdlraster = img.expression(
          '(secondBand - firstBand)/(secondIndex - firstIndex)',
          {
          'secondBand': img.select(i+1),
          'firstBand': img.select(i-1),
          'secondIndex': wl.get([i+1]),
          'firstIndex': wl.get([i-1])
          }).rename('image_Index' + str(i) + '_derivative')

      # Adds derivative bands to the input image.
      img = img.addBands(drdlraster)

    # Final image has the name of its original image reassigned.
    # This is used for file naming conventions later on.
    return img.set({'name': water.get('name')}).select(8,9,10,11,12,13,14,15,16)

  # Run the Derivative Spectra function on the test image.
  d_image = derivativeSpectra(clipped_image,band_list_early_length)
# Apply a Gaussian smoother to the image to reduce high frequency noise
#smooth_kernel hold the kernel function; select various odd values to change the kernel size.
  smooth_kernel = ee.Kernel.gaussian(radius = 3)
# apply the smoothing kernal using the ee.convolve function
  d_image = d_image.convolve(smooth_kernel)
  return d_image

# %%
# Make derivative images for all of our images of interest.
der_list = im_list.map(derivative_images)

# %% [markdown]
# # Determine Correlation Matrix for image

# %%
"""The following section is devoted to the correlation matrix
   creation process, as well as the eigen analysis."""

def pearCorr(img, starting_band_index):

  # This is distinct from the other list of band names because this is an EE object.
  # Therefore, this can utilize EE-side functions, like get().
  band_list = img.bandNames()

  # This will be filled with correlation values.
  emptyList = ee.List([])

  # Loop through band names.
  for i in band_list_forLoops:

    # Get band name based on index.
    corr_band = band_list.get(i)

    # Select the defined band from the input image.
    one = img.select([starting_band_index])

    # Select the second band of interest.
    two = img.select([corr_band])

    # Combine the two selected bands into a new image.
    cat = ee.Image.cat(one, two)

    # Compute the correlation between the bands in the newly created image.
    corr = cat.reduceRegion(
               reducer = ee.Reducer.pearsonsCorrelation(),
               geometry = roi,
               scale = native_res,
               maxPixels = maxP,
               bestEffort = True)

    # Get the correlation value out of the reduceRegion() dictionary.
    corr_value = corr.getNumber('correlation')

    # Push the new correlation value into our empty list.
    emptyList = emptyList.add(corr_value)

  return emptyList

# %%
# This code will be used for making some subfolders and writing image data to said folders.

# Convert our stack of EE images to an EE List.
image_list = der_list.toList(der_list.size())
# Get the size of the list. This will be used for the list comprehension in
# the next line.
size = image_list.size().getInfo()

# Using the variables created above, get the names of the images that we are using in our analysis.
image_names = [ee.Image(image_list.get(i)).get('name').getInfo() for i in range(size)]

# %%
image_names
# Out:
# ['20200101T160511_20200101T160506_T17RNL',
#  '20200106T160509_20200106T160506_T17RNL',
#  '20200116T160509_20200116T160505_T17RNL',
#  '20200203T160451_20200203T161119_T17RNL',
#  '20220103T160651_20220103T161400_T17RNL',
#  '20220108T160639_20220108T161304_T17RNL',
#  '20220115T160509_20220115T160507_T17RNL',
#  '20220118T160559_20220118T161203_T17RNL',
#  '20220120T160511_20220120T160511_T17RNL',
#  '20220130T160511_20220130T160511_T17RNL',
#  '20220204T160509_20220204T160505_T17RNL',
#  '20220212T160401_20220212T161135_T17RNL',
#  '20220214T160509_20220214T160505_T17RNL',
#  '20220222T160251_20220222T160752_T17RNL',
#  '20220224T160509_20220224T160506_T17RNL',
#  '20220304T160151_20220304T161444_T17RNL',
#  '20220321T160511_20220321T160514_T17RNL',
#  '20220326T160509_20220326T160508_T17RNL',
#  '20220405T160509_20220405T160508_T17RNL',
#  '20220410T160511_20220410T160513_T17RNL',
#  '20220425T160509_20220425T160505_T17RNL',
#  '20220505T160509_20220505T160507_T17RNL',
#  '20220515T160509_20220515T160510_T17RNL',
#  '20220624T160519_20220624T160516_T17RNL',
#  '20220719T160521_20220719T160523_T17RNL',
#  '20220729T160521_20220729T160521_T17RNL',
#  '20220818T160521_20220818T160524_T17RNL',
#  '20220907T160521_20220907T160523_T17RNL',
#  '20220912T160519_20220912T160513_T17RNL',
#  '20220922T160509_20220922T160512_T17RNL',
#  '20221002T160509_20221002T160510_T17RNL',
#  '20221005T160119_20221005T161213_T17RNL',
#  '20221007T160521_20221007T160518_T17RNL',
#  '20221025T160339_20221025T160825_T17RNL',
#  '20221027T160511_20221027T160514_T17RNL',
#  '20221030T160411_20221030T161121_T17RNL',
#  '20221101T160509_20221101T160509_T17RNL',
#  '20221104T160429_20221104T161233_T17RNL',
#  '20221111T160509_20221111T160510_T17RNL',
#  '20221129T160621_20221129T160726_T17RNL',
#  '20221201T160509_20221201T160509_T17RNL',
#  '20221204T160629_20221204T161443_T17RNL',
#  '20221206T160511_20221206T160512_T17RNL',
#  '20221209T160651_20221209T160831_T17RNL',
#  '20221229T160701_20221229T160923_T17RNL']

# %%
# This is where each respective image's information will be saved.
# Notice that we're using the image names we just made.
for name in image_names:
  os.mkdir(f'{output_folder}/{name}_outputs')

# %%
# List our directory of folders, which we can utilize to write files.
im_folders = os.listdir(f'{output_folder}')

# %%
# Append "_outputs" to the name of each image. Just a matter of file naming here.
im_folders = [name+'_outputs' for name in image_names]

# %%
im_folders
# Out:
# ['20200101T160511_20200101T160506_T17RNL_outputs',
#  '20200106T160509_20200106T160506_T17RNL_outputs',
#  '20200116T160509_20200116T160505_T17RNL_outputs',
#  '20200203T160451_20200203T161119_T17RNL_outputs',
#  '20200208T160419_20200208T160420_T17RNL_outputs',
#  '20200301T160511_20200301T160507_T17RNL_outputs',
#  '20200314T160021_20200314T160651_T17RNL_outputs',
#  '20200324T155911_20200324T160549_T17RNL_outputs',
#  '20200329T155819_20200329T161001_T17RNL_outputs',
#  '20200403T155901_20200403T160717_T17RNL_outputs',
#  '20200408T155819_20200408T160352_T17RNL_outputs',
#  '20200505T160509_20200505T160508_T17RNL_outputs',
#  '20200520T160521_20200520T160517_T17RNL_outputs',
#  '20220103T160651_20220103T161400_T17RNL_outputs',
#  '20220108T160639_20220108T161304_T17RNL_outputs',
#  '20220115T160509_20220115T160507_T17RNL_outputs',
#  '20220118T160559_20220118T161203_T17RNL_outputs',
#  '20220120T160511_20220120T160511_T17RNL_outputs',
#  '20220130T160511_20220130T160511_T17RNL_outputs',
#  '20220204T160509_20220204T160505_T17RNL_outputs',
#  '20220212T160401_20220212T161135_T17RNL_outputs',
#  '20220214T160509_20220214T160505_T17RNL_outputs',
#  '20220222T160251_20220222T160752_T17RNL_outputs',
#  '20220224T160509_20220224T160506_T17RNL_outputs',
#  '20220304T160151_20220304T161444_T17RNL_outputs',
#  '20220321T160511_20220321T160514_T17RNL_outputs',
#  '20220326T160509_20220326T160508_T17RNL_outputs',
#  '20220405T160509_20220405T160508_T17RNL_outputs',
#  '20220410T160511_20220410T160513_T17RNL_outputs',
#  '20220425T160509_20220425T160505_T17RNL_outputs',
#  '20220505T160509_20220505T160507_T17RNL_outputs',
#  '20220515T160509_20220515T160510_T17RNL_outputs',
#  '20220624T160519_20220624T160516_T17RNL_outputs',
#  '20220719T160521_20220719T160523_T17RNL_outputs',
#  '20220729T160521_20220729T160521_T17RNL_outputs',
#  '20220818T160521_20220818T160524_T17RNL_outputs',
#  '20220907T160521_20220907T160523_T17RNL_outputs',
#  '20220912T160519_20220912T160513_T17RNL_outputs',
#  '20220922T160509_20220922T160512_T17RNL_outputs',
#  '20221002T160509_20221002T160510_T17RNL_outputs',
#  '20221005T160119_20221005T161213_T17RNL_outputs',
#  '20221007T160521_20221007T160518_T17RNL_outputs',
#  '20221025T160339_20221025T160825_T17RNL_outputs',
#  '20221027T160511_20221027T160514_T17RNL_outputs',
#  '20221030T160411_20221030T161121_T17RNL_outputs',
#  '20221101T160509_20221101T160509_T17RNL_outputs',
#  '20221104T160429_20221104T161233_T17RNL_outputs',
#  '20221111T160509_20221111T160510_T17RNL_outputs',
#  '20221129T160621_20221129T160726_T17RNL_outputs',
#  '20221201T160509_20221201T160509_T17RNL_outputs',
#  '20221204T160629_20221204T161443_T17RNL_outputs',
#  '20221206T160511_20221206T160512_T17RNL_outputs',
#  '20221209T160651_20221209T160831_T17RNL_outputs',
#  '20221229T160701_20221229T160923_T17RNL_outputs']

# %%
# Here, we export our correlation matrices and pixel counts.
def export_corr(d_image, out):
  d_image = ee.Image(d_image)

  # List comprehension to compile all of our correlation values (per image).
  # We also grab the number of pixels visible in the image, which is used for weighting.
  corr_ls = ee.Feature(None, {'correlation_list':[pearCorr(d_image, i) for i in band_list_forLoops],
                              'pixel_count': d_image.reduceRegion(ee.Reducer.count(),roi,maxPixels = maxP, scale = native_res, bestEffort = True, tileScale = 16).get('image_Index0_derivative')})

  # Name our output file.
  runtime_filename = f'6VPCA_{siteName_2char}_{d_image.get("name").getInfo()}_correlation_{bandCombo}'

  # Create our export task.
  intermission = ( batch.Export.table.toDrive(
                   collection = ee.FeatureCollection(corr_ls),
                   description = runtime_filename,
                   fileFormat = 'CSV') )

  # Initialize our task.
  batch.Task.start(intermission)

  # Monitor the task.
  i = 1
  # While running, give us an update.
  while intermission.status()['state'] in ['READY', 'RUNNING']:
    sys.stdout.write("\r" + f'Correlation export status update #{i}: ' + str(intermission.status()))
    sys.stdout.flush()
    i += 1
    time.sleep(20)

  # When finished running, let us know what happened.
  else:
    print('Correlation export completed...')
    print(intermission.status())
    # Give your Drive a chance to update with changes made to your storage.
    time.sleep(20)

    # Move your newly created files to the places they need to be.
    try:
      # Found here: https://stackoverflow.com/questions/51109931/moving-files-in-google-colab
      shutil.move(f'/content/gdrive/My Drive/{runtime_filename}.csv',f'{output_folder}/{out}')

    except:
      time.sleep(60)
      shutil.move(f'/content/gdrive/My Drive/{runtime_filename}.csv',f'{output_folder}/{out}')

# Run the correlation export for every file in our image stack.
for i in range(len(im_folders)):
  export_corr(image_list.get(i),im_folders[i])
# Out:
# Correlation export status update #4: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200101T160511_20200101T160506_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680640451376, 'update_timestamp_ms': 1680640475841, 'start_timestamp_ms': 1680640475808, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'LC3TMSTQDNQHUPQ7CBGIETMS', 'name': 'projects/earthengine-legacy/operations/LC3TMSTQDNQHUPQ7CBGIETMS'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200101T160511_20200101T160506_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680640451376, 'update_timestamp_ms': 1680640528556, 'start_timestamp_ms': 1680640475808, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 5465.03564453125, 'id': 'LC3TMSTQDNQHUPQ7CBGIETMS', 'name': 'projects/earthengine-legacy/operations/LC3TMSTQDNQHUPQ7CBGIETMS'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200106T160509_20200106T160506_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680640558633, 'update_timestamp_ms': 1680640572921, 'start_timestamp_ms': 1680640572888, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'LNRJVDXLOVUJ7SUOQI5EYRH3', 'name': 'projects/earthengine-legacy/operations/LNRJVDXLOVUJ7SUOQI5EYRH3'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200106T160509_20200106T160506_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680640558633, 'update_timestamp_ms': 1680640615223, 'start_timestamp_ms': 1680640572888, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 3577.520263671875, 'id': 'LNRJVDXLOVUJ7SUOQI5EYRH3', 'name': 'projects/earthengine-legacy/operations/LNRJVDXLOVUJ7SUOQI5EYRH3'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200116T160509_20200116T160505_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680640648873, 'update_timestamp_ms': 1680640659641, 'start_timestamp_ms': 1680640659608, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'BFPXI3XRULHJL4HWHZZDC6OT', 'name': 'projects/earthengine-legacy/operations/BFPXI3XRULHJL4HWHZZDC6OT'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200116T160509_20200116T160505_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680640648873, 'update_timestamp_ms': 1680640692460, 'start_timestamp_ms': 1680640659608, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 5589.28076171875, 'id': 'BFPXI3XRULHJL4HWHZZDC6OT', 'name': 'projects/earthengine-legacy/operations/BFPXI3XRULHJL4HWHZZDC6OT'}
# Correlation export status update #4: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200203T160451_20200203T161119_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680640733929, 'update_timestamp_ms': 1680640762786, 'start_timestamp_ms': 1680640762752, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'MM6CYKVQUCDRREQUBT4XFUKS', 'name': 'projects/earthengine-legacy/operations/MM6CYKVQUCDRREQUBT4XFUKS'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200203T160451_20200203T161119_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680640733929, 'update_timestamp_ms': 1680640801873, 'start_timestamp_ms': 1680640762752, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 6537.2666015625, 'id': 'MM6CYKVQUCDRREQUBT4XFUKS', 'name': 'projects/earthengine-legacy/operations/MM6CYKVQUCDRREQUBT4XFUKS'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20
 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4446.4296875, 'id': 'PAFGA2A6KW4DFFZOGGL7ZA7N', 'name': 'projects/earthengine-legacy/operations/PAFGA2A6KW4DFFZOGGL7ZA7N'}
# Correlation export status update #2: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200408T155819_20200408T160352_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680641444567, 'update_timestamp_ms': 1680641457401, 'start_timestamp_ms': 1680641457369, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'T75DOTR65PEQWLO6BKAQAFRU', 'name': 'projects/earthengine-legacy/operations/T75DOTR65PEQWLO6BKAQAFRU'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200408T155819_20200408T160352_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680641444567, 'update_timestamp_ms': 1680641484665, 'start_timestamp_ms': 1680641457369, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4336.7822265625, 'id': 'T75DOTR65PEQWLO6BKAQAFRU', 'name': 'projects/earthengine-legacy/operations/T75DOTR65PEQWLO6BKAQAFRU'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200505T160509_20200505T160508_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680641568974, 'update_timestamp_ms': 1680641590288, 'start_timestamp_ms': 1680641590255, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': '6XFZVXXGXO4ZE4F3QYRPIEPY', 'name': 'projects/earthengine-legacy/operations/6XFZVXXGXO4ZE4F3QYRPIEPY'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200505T160509_20200505T160508_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680641568974, 'update_timestamp_ms': 1680641612102, 'start_timestamp_ms': 1680641590255, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4348.3037109375, 'id': '6XFZVXXGXO4ZE4F3QYRPIEPY', 'name': 'projects/earthengine-legacy/operations/6XFZVXXGXO4ZE4F3QYRPIEPY'}
# Correlation export status update #4: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200520T160521_20200520T160517_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680641655415, 'update_timestamp_ms': 1680641717055, 'start_timestamp_ms': 1680641667404, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': '2OKWVLBNTRATJRTQTPAZR4XF', 'name': 'projects/earthengine-legacy/operations/2OKWVLBNTRATJRTQTPAZR4XF'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200520T160521_20200520T160517_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680641655415, 'update_timestamp_ms': 1680641718040, 'start_timestamp_ms': 1680641667404, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 6163.845703125, 'id': '2OKWVLBNTRATJRTQTPAZR4XF', 'name': 'projects/earthengine-legacy/operations/2OKWVLBNTRATJRTQTPAZR4XF'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200624T160519_20200624T160513_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680641764757, 'update_timestamp_ms': 1680641775788, 'start_timestamp_ms': 1680641775755, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'N6TQSASE2DLFE7BBDXCJWHAS', 'name': 'projects/earthengine-legacy/operations/N6TQSASE2DLFE7BBDXCJWHAS'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200624T160519_20200624T160513_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680641764757, 'update_timestamp_ms': 1680641812392, 'start_timestamp_ms': 1680641775755, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 5921.03515625, 'id': 'N6TQSASE2DLFE7BBDXCJWHAS', 'name': 'projects/earthengine-legacy/operations/N6TQSASE2DLFE7BBDXCJWHAS'}
# Correlation export status update #4: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200629T160521_20200629T160516_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680641850803, 'update_timestamp_ms': 1680641864710, 'start_timestamp_ms': 1680641864677, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'KFIGXNBVEOAOPJEOBGFT3FW4', 'name': 'projects/earthengine-legacy/operations/KFIGXNBVEOAOPJEOBGFT3FW4'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200629T160521_20200629T160516_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680641850803, 'update_timestamp_ms': 1680641914318, 'start_timestamp_ms': 1680641864677, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 6547.7626953125, 'id': 'KFIGXNBVEOAOPJEOBGFT3FW4', 'name': 'projects/earthengine-legacy/operations/KFIGXNBVEOAOPJEOBGFT3FW4'}
# Correlation export status update #4: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200714T160509_20200714T160512_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680641956223, 'update_timestamp_ms': 1680641983629, 'start_timestamp_ms': 1680641983596, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': '5MIQBS2RRXUHG3G4N4Y6UN36', 'name': 'projects/earthengine-legacy/operations/5MIQBS2RRXUHG3G4N4Y6UN36'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200714T160509_20200714T160512_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680641956223, 'update_timestamp_ms': 1680642036721, 'start_timestamp_ms': 1680641983596, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4281.6015625, 'id': '5MIQBS2RRXUHG3G4N4Y6UN36', 'name': 'projects/earthengine-legacy/operations/5MIQBS2RRXUHG3G4N4Y6UN36'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200719T160521_20200719T160516_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680642121593, 'update_timestamp_ms': 1680642130664, 'start_timestamp_ms': 1680642130631, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': '6TPZ2NVHZTODWSD4KTXB53HB', 'name': 'projects/earthengine-legacy/operations/6TPZ2NVHZTODWSD4KTXB53HB'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200719T160521_20200719T160516_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680642121593, 'update_timestamp_ms': 1680642166191, 'start_timestamp_ms': 1680642130631, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4071.5458984375, 'id': '6TPZ2NVHZTODWSD4KTXB53HB', 'name': 'projects/earthengine-legacy/operations/6TPZ2NVHZTODWSD4KTXB53HB'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200724T160519_20200724T160513_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680642207547, 'update_timestamp_ms': 1680642248951, 'start_timestamp_ms': 1680642225073, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': '3AU26KEWD2HB5GQK76CABE4E', 'name': 'projects/earthengine-legacy/operations/3AU26KEWD2HB5GQK76CABE4E'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200724T160519_20200724T160513_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680642207547, 'update_timestamp_ms': 1680642250250, 'start_timestamp_ms': 1680642225073, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4593.11328125, 'id': '3AU26KEWD2HB5GQK76CABE4E', 'name': 'projects/earthengine-legacy/operations/3AU26KEWD2HB5GQK76CABE4E'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200808T160521_20200808T160517_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680642296629, 'update_timestamp_ms': 1680642307995, 'start_timestamp_ms': 1680642307959, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': '6KSR7L27PM74BJKBU5XQ4KGL', 'name': 'projects/earthengine-legacy/operations/6KSR7L27PM74BJKBU5XQ4KGL'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200808T160521_20200808T160517_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680642296629, 'update_timestamp_ms': 1680642345066, 'start_timestamp_ms': 1680642307959, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 5538.5322265625, 'id': '6KSR7L27PM74BJKBU5XQ4KGL', 'name': 'projects/earthengine-legacy/operations/6KSR7L27PM74BJKBU5XQ4KGL'}
# Correlation export status update #2: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200813T160519_20200813T160514_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680642381751, 'update_timestamp_ms': 1680642395750, 'start_timestamp_ms': 1680642395718, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'PKECPJW4M3URK35RCBOXOIBP', 'name': 'projects/earthengine-legacy/operations/PKECPJW4M3URK35RCBOXOIBP'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200813T160519_20200813T160514_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680642381751, 'update_timestamp_ms': 1680642421528, 'start_timestamp_ms': 1680642395718, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 5568.78466796875, 'id': 'PKECPJW4M3URK35RCBOXOIBP', 'name': 'projects/earthengine-legacy/operations/PKECPJW4M3URK35RCBOXOIBP'}
# Correlation export status update #2: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200902T160519_20200902T160514_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680642508758, 'update_timestamp_ms': 1680642515627, 'start_timestamp_ms': 1680642515593, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'AI4AS2NAS2GDL6GC77JMX6HL', 'name': 'projects/earthengine-legacy/operations/AI4AS2NAS2GDL6GC77JMX6HL'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20200902T160519_20200902T160514_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680642508758, 'update_timestamp_ms': 1680642549558, 'start_timestamp_ms': 1680642515593, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 3980.240966796875, 'id': 'AI4AS2NAS2GDL6GC77JMX6HL', 'name': 'projects/earthengine-legacy/operations/AI4AS2NAS2GDL6GC77JMX6HL'}
# Correlation export status update #5: {'state': 'RUNNING', 'description': '6VPCA_IRL_20200917T160521_20200917T160516_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680
}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20201221T160509_20201221T160507_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680643089745, 'update_timestamp_ms': 1680643163963, 'start_timestamp_ms': 1680643107103, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 5862.59619140625, 'id': 'PPBHNQZVNCLP7X2IEL2X4FLC', 'name': 'projects/earthengine-legacy/operations/PPBHNQZVNCLP7X2IEL2X4FLC'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20201229T160651_20201229T161425_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680643195137, 'update_timestamp_ms': 1680643209882, 'start_timestamp_ms': 1680643209850, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': '5FK5BX3TUUJ4EVE45AZWRBVW', 'name': 'projects/earthengine-legacy/operations/5FK5BX3TUUJ4EVE45AZWRBVW'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20201229T160651_20201229T161425_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680643195137, 'update_timestamp_ms': 1680643245906, 'start_timestamp_ms': 1680643209850, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4275.27978515625, 'id': '5FK5BX3TUUJ4EVE45AZWRBVW', 'name': 'projects/earthengine-legacy/operations/5FK5BX3TUUJ4EVE45AZWRBVW'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210105T160511_20210105T160512_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680643283667, 'update_timestamp_ms': 1680643303121, 'start_timestamp_ms': 1680643303088, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ULHELSAUY4RGYJ5PSP3K3IAC', 'name': 'projects/earthengine-legacy/operations/ULHELSAUY4RGYJ5PSP3K3IAC'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210105T160511_20210105T160512_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680643283667, 'update_timestamp_ms': 1680643339891, 'start_timestamp_ms': 1680643303088, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4128.7392578125, 'id': 'ULHELSAUY4RGYJ5PSP3K3IAC', 'name': 'projects/earthengine-legacy/operations/ULHELSAUY4RGYJ5PSP3K3IAC'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210120T160509_20210120T160511_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680643369427, 'update_timestamp_ms': 1680643387257, 'start_timestamp_ms': 1680643387224, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'TSIIS3X5PHQP4F4PUA4ZSICU', 'name': 'projects/earthengine-legacy/operations/TSIIS3X5PHQP4F4PUA4ZSICU'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210120T160509_20210120T160511_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680643369427, 'update_timestamp_ms': 1680643427594, 'start_timestamp_ms': 1680643387224, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 5505.1396484375, 'id': 'TSIIS3X5PHQP4F4PUA4ZSICU', 'name': 'projects/earthengine-legacy/operations/TSIIS3X5PHQP4F4PUA4ZSICU'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210128T160521_20210128T161127_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680643455005, 'update_timestamp_ms': 1680643469581, 'start_timestamp_ms': 1680643469579, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZU22HXDAAB3P3XEODLAUE7PP', 'name': 'projects/earthengine-legacy/operations/ZU22HXDAAB3P3XEODLAUE7PP'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210128T160521_20210128T161127_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680643455005, 'update_timestamp_ms': 1680643505288, 'start_timestamp_ms': 1680643469579, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 3730.0615234375, 'id': 'ZU22HXDAAB3P3XEODLAUE7PP', 'name': 'projects/earthengine-legacy/operations/ZU22HXDAAB3P3XEODLAUE7PP'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210202T160459_20210202T160957_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680643546709, 'update_timestamp_ms': 1680643553855, 'start_timestamp_ms': 1680643553818, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': '7NSXJBCG35ORENKKO4FSAHPM', 'name': 'projects/earthengine-legacy/operations/7NSXJBCG35ORENKKO4FSAHPM'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210202T160459_20210202T160957_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680643546709, 'update_timestamp_ms': 1680643594019, 'start_timestamp_ms': 1680643553818, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 6478.7548828125, 'id': '7NSXJBCG35ORENKKO4FSAHPM', 'name': 'projects/earthengine-legacy/operations/7NSXJBCG35ORENKKO4FSAHPM'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210219T160509_20210219T160509_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680
 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4216.59619140625, 'id': 'JSJFPXISJJH6MTBLM4I6YJEC', 'name': 'projects/earthengine-legacy/operations/JSJFPXISJJH6MTBLM4I6YJEC'}
# Correlation export status update #2: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210311T160509_20210311T160510_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644249644, 'update_timestamp_ms': 1680644261054, 'start_timestamp_ms': 1680644261019, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'TGYGMDGUD7DD6BOBCVTQUU2H', 'name': 'projects/earthengine-legacy/operations/TGYGMDGUD7DD6BOBCVTQUU2H'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210311T160509_20210311T160510_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644249644, 'update_timestamp_ms': 1680644287165, 'start_timestamp_ms': 1680644261019, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 3625.475830078125, 'id': 'TGYGMDGUD7DD6BOBCVTQUU2H', 'name': 'projects/earthengine-legacy/operations/TGYGMDGUD7DD6BOBCVTQUU2H'}
# Correlation export status update #2: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210314T155929_20210314T160346_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644313876, 'update_timestamp_ms': 1680644326644, 'start_timestamp_ms': 1680644326609, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'PYEQQSA4A47HHN4IBT3PMVLL', 'name': 'projects/earthengine-legacy/operations/PYEQQSA4A47HHN4IBT3PMVLL'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210314T155929_20210314T160346_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644313876, 'update_timestamp_ms': 1680644347952, 'start_timestamp_ms': 1680644326609, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4107.560546875, 'id': 'PYEQQSA4A47HHN4IBT3PMVLL', 'name': 'projects/earthengine-legacy/operations/PYEQQSA4A47HHN4IBT3PMVLL'}
# Correlation export status update #5: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210319T155951_20210319T161024_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644378363, 'update_timestamp_ms': 1680644410620, 'start_timestamp_ms': 1680644410586, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'NVVCSEIK6MFHTFIT4PYQD6Z7', 'name': 'projects/earthengine-legacy/operations/NVVCSEIK6MFHTFIT4PYQD6Z7'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210319T155951_20210319T161024_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644378363, 'update_timestamp_ms': 1680644470557, 'start_timestamp_ms': 1680644410586, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 7656.63330078125, 'id': 'NVVCSEIK6MFHTFIT4PYQD6Z7', 'name': 'projects/earthengine-legacy/operations/NVVCSEIK6MFHTFIT4PYQD6Z7'}
# Correlation export status update #5: {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210324T155819_20210324T160756_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644504375, 'update_timestamp_ms': 1680644586667, 'start_timestamp_ms': 1680644517841, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 5957.65673828125, 'id': 'S3RAZHMNZSWOVM2GLXARTJSG', 'name': 'projects/earthengine-legacy/operations/S3RAZHMNZSWOVM2GLXARTJSG'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210324T155819_20210324T160756_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644504375, 'update_timestamp_ms': 1680644586667, 'start_timestamp_ms': 1680644517841, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 5957.65673828125, 'id': 'S3RAZHMNZSWOVM2GLXARTJSG', 'name': 'projects/earthengine-legacy/operations/S3RAZHMNZSWOVM2GLXARTJSG'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210405T160511_20210405T160507_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644690126, 'update_timestamp_ms': 1680644701646, 'start_timestamp_ms': 1680644701613, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'TF32D7J4GDLGSFGBUB4BUPZP', 'name': 'projects/earthengine-legacy/operations/TF32D7J4GDLGSFGBUB4BUPZP'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210405T160511_20210405T160507_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644690126, 'update_timestamp_ms': 1680644735605, 'start_timestamp_ms': 1680644701613, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 6571.9248046875, 'id': 'TF32D7J4GDLGSFGBUB4BUPZP', 'name': 'projects/earthengine-legacy/operations/TF32D7J4GDLGSFGBUB4BUPZP'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210410T160509_20210410T160515_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644775245, 'update_timestamp_ms': 1680644794114, 'start_timestamp_ms': 1680644794081, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'LO73PRBRZTHX3EPV4H3BCUHF', 'name': 'projects/earthengine-legacy/operations/LO73PRBRZTHX3EPV4H3BCUHF'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210410T160509_20210410T160515_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644775245, 'update_timestamp_ms': 1680644819944, 'start_timestamp_ms': 1680644794081, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 5515.80419921875, 'id': 'LO73PRBRZTHX3EPV4H3BCUHF', 'name': 'projects/earthengine-legacy/operations/LO73PRBRZTHX3EPV4H3BCUHF'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210430T160509_20210430T160507_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644860305, 'update_timestamp_ms': 1680644901075, 'start_timestamp_ms': 1680644875305, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'LFXT7ROSRHULW5OREBBKGSGN', 'name': 'projects/earthengine-legacy/operations/LFXT7ROSRHULW5OREBBKGSGN'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210430T160509_20210430T160507_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644860305, 'update_timestamp_ms': 1680644902111, 'start_timestamp_ms': 1680644875305, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 6600.65234375, 'id': 'LFXT7ROSRHULW5OREBBKGSGN', 'name': 'projects/earthengine-legacy/operations/LFXT7ROSRHULW5OREBBKGSGN'}
# Correlation export status update #2: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210505T160511_20210505T160510_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644945832, 'update_timestamp_ms': 1680644954156, 'start_timestamp_ms': 1680644954123, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'SUJUMUSMI5XGCSBW7LPK43P5', 'name': 'projects/earthengine-legacy/operations/SUJUMUSMI5XGCSBW7LPK43P5'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210505T160511_20210505T160510_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680644945832, 'update_timestamp_ms': 1680644980532, 'start_timestamp_ms': 1680644954123, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4120.60400390625, 'id': 'SUJUMUSMI5XGCSBW7LPK43P5', 'name': 'projects/earthengine-legacy/operations/SUJUMUSMI5XGCSBW7LPK43P5'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210510T160509_20210510T160509_T17RNM_correlation_B1-B8A', 'creation_timestamp_ms': 1680645010936, 'update_timestamp_ms': 1680645041844, 'start_timestamp_ms': 1680645041768, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'TSFFPIPPNCJ6E53TE33I4LWM', 'name': 'projects/earthengine-legacy/operations/TSFFPIPPNCJ6E53TE33I4LWM'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210510T160509_20210510T160509_T17RNM_correlation_B1-B8A', 'creation_timestamp_ms': 1680645010936, 'update_timestamp_ms': 1680645071711, 'start_timestamp_ms': 1680645041768, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 6178.3232421875, 'id': 'TSFFPIPPNCJ6E53TE33I4LWM', 'name': 'projects/earthengine-legacy/operations/TSFFPIPPNCJ6E53TE33I4LWM'}
# Correlation export status update #5: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210515T160511_20210515T160511_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680645156289, 'update_timestamp_ms': 1680645218583, 'start_timestamp_ms': 1680645218505, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'EVSMKHL65PLDDZFJLIG3LUCL', 'name': 'projects/earthengine-legacy/operations/EVSMKHL65PLDDZFJLIG3LUCL'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210515T160511_20210515T160511_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680645156289, 'update_timestamp_ms': 1680645240898, 'start_timestamp_ms': 1680645218505, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4334.7158203125, 'id': 'EVSMKHL65PLDDZFJLIG3LUCL', 'name': 'projects/earthengine-legacy/operations/EVSMKHL65PLDDZFJLIG3LUCL'}
# Correlation export status update #5: {'state': 'RUNNING', 'description': '6VPCA_IRL_20210525T160511_20210525T160512_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680645282630, 'update_timestamp_ms': 1680645325013, 'start_timestamp_ms': 1680645324935, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'GBAORZ2DGPSUW6UJVL6JBHE2', 'name': 'projects/earthengine-legacy/operations/GBAORZ2DGPSUW6UJVL6JBHE2'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20210525T160511_20210525T160512_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680645282630, 'update_timestamp_ms': 1680645373562, 'start_timestamp_ms': 1680645324935, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 
 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 7586.0283203125, 'id': 'M32X26SMAPRSWDWB73K23LGP', 'name': 'projects/earthengine-legacy/operations/M32X26SMAPRSWDWB73K23LGP'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20221206T160511_20221206T160512_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680652014373, 'update_timestamp_ms': 1680652048478, 'start_timestamp_ms': 1680652048399, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'LNKGUYMO6FDGZLLNGTFXCEE2', 'name': 'projects/earthengine-legacy/operations/LNKGUYMO6FDGZLLNGTFXCEE2'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20221206T160511_20221206T160512_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680652014373, 'update_timestamp_ms': 1680652072311, 'start_timestamp_ms': 1680652048399, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 3986.922607421875, 'id': 'LNKGUYMO6FDGZLLNGTFXCEE2', 'name': 'projects/earthengine-legacy/operations/LNKGUYMO6FDGZLLNGTFXCEE2'}
# Correlation export status update #3: {'state': 'RUNNING', 'description': '6VPCA_IRL_20221209T160651_20221209T160831_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680652099250, 'update_timestamp_ms': 1680652129028, 'start_timestamp_ms': 1680652128952, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'OCVFHZKCRIYWKRVNOKLIERK2', 'name': 'projects/earthengine-legacy/operations/OCVFHZKCRIYWKRVNOKLIERK2'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20221209T160651_20221209T160831_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680652099250, 'update_timestamp_ms': 1680652157399, 'start_timestamp_ms': 1680652128952, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 4677.15966796875, 'id': 'OCVFHZKCRIYWKRVNOKLIERK2', 'name': 'projects/earthengine-legacy/operations/OCVFHZKCRIYWKRVNOKLIERK2'}
# Correlation export status update #4: {'state': 'RUNNING', 'description': '6VPCA_IRL_20221229T160701_20221229T160923_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680652184264, 'update_timestamp_ms': 1680652205218, 'start_timestamp_ms': 1680652205141, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ROR3LEI2BHDCFLXZGW6FK7WI', 'name': 'projects/earthengine-legacy/operations/ROR3LEI2BHDCFLXZGW6FK7WI'}Correlation export completed...
# {'state': 'COMPLETED', 'description': '6VPCA_IRL_20221229T160701_20221229T160923_T17RNL_correlation_B1-B8A', 'creation_timestamp_ms': 1680652184264, 'update_timestamp_ms': 1680652259799, 'start_timestamp_ms': 1680652205141, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://drive.google.com/'], 'attempt': 1, 'batch_eecu_usage_seconds': 6401.72998046875, 'id': 'ROR3LEI2BHDCFLXZGW6FK7WI', 'name': 'projects/earthengine-legacy/operations/ROR3LEI2BHDCFLXZGW6FK7WI'}

# %% [markdown]
# # Begin section for correlation graph

# %%
# Find all of the files in our output folder.
csv_files = []
# For a description of the functionality of os.walk(), see below:
# https://www.tutorialspoint.com/python/os_walk.htm
for subdir, dirs, files in os.walk(f'{output_folder}'):
  for file in files:
    if "_correlation" in file and "Viz" not in file and 'gsheet' not in file:
      csv_files += [os.path.join(subdir,file)]

# %%
csv_files
# Out:
# ['/content/gdrive/My Drive/test_FL_DEP/20200101T160511_20200101T160506_T17RNL_outputs/6VPCA_IRL_20200101T160511_20200101T160506_T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20200106T160509_20200106T160506_T17RNL_outputs/6VPCA_IRL_20200106T160509_20200106T160506_T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20200116T160509_20200116T160505_T17RNL_outputs/6VPCA_IRL_20200116T160509_20200116T160505_T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20200203T160451_20200203T161119_T17RNL_outputs/6VPCA_IRL_20200203T160451_20200203T161119_T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20200208T160419_20200208T160420_T17RNL_outputs/6VPCA_IRL_20200208T160419_20200208T160420_T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20200301T160511_20200301T160507_T17RNL_outputs/6VPCA_IRL_20200301T160511_20200301T160507_T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20
T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20221111T160509_20221111T160510_T17RNL_outputs/6VPCA_IRL_20221111T160509_20221111T160510_T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20221129T160621_20221129T160726_T17RNL_outputs/6VPCA_IRL_20221129T160621_20221129T160726_T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20221201T160509_20221201T160509_T17RNL_outputs/6VPCA_IRL_20221201T160509_20221201T160509_T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20221204T160629_20221204T161443_T17RNL_outputs/6VPCA_IRL_20221204T160629_20221204T161443_T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20221206T160511_20221206T160512_T17RNL_outputs/6VPCA_IRL_20221206T160511_20221206T160512_T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20221209T160651_20221209T160831_T17RNL_outputs/6VPCA_IRL_20221209T160651_20221209T160831_T17RNL_correlation_B1-B8A.csv',
#  '/content/gdrive/My Drive/test_FL_DEP/20221229T160701_20221229T160923_T17RNL_outputs/6VPCA_IRL_20221229T160701_20221229T160923_T17RNL_correlation_B1-B8A.csv']

# %%
# counter
i = 0

for fn in csv_files:

  # First, load our csv file into a Pandas DataFrame.
  drive_string = fn
  dataframe = pd.read_csv(drive_string, delimiter = ',', converters = {'correlation_list': eval})

  # Next, convert our dataframe to a list.
  print (dataframe)
  corr_ls = dataframe['correlation_list'].tolist()[0]

  # Initially found here: https://stackoverflow.com/questions/33282368/plotting-a-2d-heatmap-with-matplotlib
  # Create a 2D heat map using Seaborn.

  # Use this code to allow for differing number of bands processed
  labels = [f'd{non_ee_band_list[x]}' for x in range(band_list_early_length)]

  # Mask redundant info from the correlation array visualization.
  mask = np.zeros_like(corr_ls)
  mask[np.triu_indices_from(mask)] = True

  # Create matplotlib figure to place our heatmap in.
  fig = plt.figure(figsize = (20,20))
  heat = sea.heatmap(corr_ls, square = False, mask = mask, cmap = 'coolwarm', annot = True)
  heat.set_xticklabels(labels)
  heat.set_yticklabels(labels)

  for tick in heat.get_yticklabels():
    tick.set_rotation(0)

  heat.set_title(f"Correlation Matrix: {image_names[i]}")

  plt.savefig(f'{output_folder}/{im_folders[i]}/{image_names[i]}_correlationViz.jpg')
  i += 1
# Out:
#    system:index                                   correlation_list  \
# 0             0  [[1.0, -0.19911821364655055, 0.008012277089886...
#
#    pixel_count                                    .geo
# 0        34026  {"type":"MultiPoint","coordinates":[]}
#    system:index                                   correlation_list  \
# 0             0  [[1.0, -0.20854482422698195, 0.015946995864215...
#
#    pixel_count                                    .geo
# 0        35552  {"type":"MultiPoint","coordinates":[]}
#    system:index                                   correlation_list  \
# 0             0  [[1.0, -0.13972880845017324, 0.146811556450223...
#
#    pixel_count                                    .geo
# 0        35118  {"type":"MultiPoint","coordinates":[]}
#    system:index                                   correlation_list  \
# 0             0  [[1.0, -0.1292176926377249, 0.0288704449469529...
#
#    pixel_count                                    .geo
# 0        39169  {"type":"MultiPoint","coordinates":[]}
#    system:index                                   correlation_list  \
# 0             0  [[1.0, -0.12891972067102717, -0.04105340633337...
#
#    pixel_count                                    .geo
# 0        36251  {"type":"MultiPoint","coordinates":[]}
#    system:index                                   correlation_list  \
# 0             0  [[1.0, -0.16277845248248207, 0.051970892977854...
#
#    pixel_count                                    .geo
# 0        35523  {"type":"MultiPoint","coordinates":[]}
